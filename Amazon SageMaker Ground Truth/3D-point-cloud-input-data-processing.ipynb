# %% [markdown]
# # Create a 3D Point Cloud Labeling Job for Object Tracking with Amazon SageMaker Ground Truth

# %% [markdown]
# ---
#
# This notebook's CI test result for us-west-2 is as follows. CI test results in other regions can be found at the end of the notebook.
#
# ![This us-west-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/us-west-2/ground_truth_labeling_jobs|3d_point_cloud_input_data_processing|3D-point-cloud-input-data-processing.ipynb)
#
# ---

# %% [markdown]
# This notebook will demonstrate how you can pre-process your 3D point cloud input data to create an [object tracking labeling job](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-point-cloud-object-tracking.html) and include sensor and camera data for sensor fusion.
#
# In object tracking, you are tracking the movement of an object (e.g., a pedestrian on the side walk) while your point of reference (e.g., the autonomous vehicle) is moving. When performing object tracking, your data must be in a global reference coordinate system such as [world coordinate system](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-point-cloud-sensor-fusion-details.html#sms-point-cloud-world-coordinate-system) because the ego vehicle itself is moving in the world. You can transform point cloud data in local coordinates to the world coordinate system by multiplying each of the points in a 3D frame with the extrinsic matrix for the LiDAR sensor.
#
# In this notebook, you will transform 3D frames from a local coordinate system to a world coordinate system using extrinsic matrices. You will use the KITTI dataset<sup>[1](#The-Dataset-and-Input-Manifest-Files)</sup>, an open source autonomous driving dataset. The KITTI dataset provides an extrinsic matrix for each 3D point cloud frame. You will use [pykitti](https://github.com/utiasSTARS/pykitti) and the [numpy matrix multiplication function](https://numpy.org/doc/1.18/reference/generated/numpy.matmul.html) to multiple this matrix with each point in the frame to translate that point to the world coordinate system used by the KITTI dataset.
#
# You include camera image data and provide workers with more visual information about the scene they are labeling. Through sensor fusion, workers will be able to adjust labels in the 3D scene and in 2D images, and label adjustments will be mirrored in the other view.
#
# Ground Truth computes your sensor and camera extrinsic matrices for sensor fusion using sensor and camera **pose data** - position and heading. The KITTI raw dataset includes rotation matrix and translations vectors for extrinsic transformations for each frame. This notebook will demonstrate how you can extract **position** and **heading** from KITTI rotation matrices and translations vectors using [pykitti](https://github.com/utiasSTARS/pykitti).
#
# In summary, you will:
# * Convert a dataset to a world coordinate system.
# * Learn how you can extract pose data from your LiDAR and camera extrinsict matrices for sensor fusion.
# * Create a sequence input manifest file for an object tracking labeling job.
# * Create an object tracking labeling job.
# * Preview the worker UI and tools provided by Ground Truth.
#
#
# ## Prerequisites
#
# To run this notebook, you can simply execute each cell in order. To understand what's happening, you'll need:
# * An S3 bucket you can write to -- please provide its name in `BUCKET`. The bucket must be in the same region as this SageMaker Notebook instance. You can also change the `EXP_NAME` to any valid S3 prefix. All the files related to this experiment will be stored in that prefix of your bucket. **Important: you must attach the CORS policy to this bucket. See the next section for more information**.
# * Familiarity with the [Ground Truth 3D Point Cloud Labeling Job](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-point-cloud.html).
# * Familiarity with Python and [numpy](http://www.numpy.org/).
# * Basic familiarity with [AWS S3](https://docs.aws.amazon.com/s3/index.html).
# * Basic understanding of [AWS Sagemaker](https://aws.amazon.com/sagemaker/).
# * Basic familiarity with [AWS Command Line Interface (CLI)](https://aws.amazon.com/cli/) -- ideally, you should have it set up with credentials to access the AWS account you're running this notebook from.
#
# This notebook has only been tested on a SageMaker notebook instance. The runtimes given are approximate. We used an `ml.t2.medium` instance in our tests. However, you can likely run it on a local instance by first executing the cell below on SageMaker and then copying the `role` string to your local copy of the notebook.

# %% [markdown]
# ### IMPORTANT: Attach CORS policy to your bucket
#
# You must attach the following CORS policy to your S3 bucket for the labeling task to render. To learn how to add a CORS policy to your S3 bucket, follow the instructions in [How do I add cross-domain resource sharing with CORS?](https://docs.aws.amazon.com/AmazonS3/latest/user-guide/add-cors-configuration.html). Paste the following policy in the CORS configuration editor:
#
# ```
# <?xml version="1.0" encoding="UTF-8"?>
# <CORSConfiguration xmlns="http://s3.amazonaws.com/doc/2006-03-01/">
# <CORSRule>
#     <AllowedOrigin>*</AllowedOrigin>
#     <AllowedMethod>GET</AllowedMethod>
#     <AllowedMethod>HEAD</AllowedMethod>
#     <AllowedMethod>PUT</AllowedMethod>
#     <MaxAgeSeconds>3000</MaxAgeSeconds>
#     <ExposeHeader>Access-Control-Allow-Origin</ExposeHeader>
#     <AllowedHeader>*</AllowedHeader>
# </CORSRule>
# <CORSRule>
#     <AllowedOrigin>*</AllowedOrigin>
#     <AllowedMethod>GET</AllowedMethod>
# </CORSRule>
# </CORSConfiguration>
# ```

# %%
# !pip install boto3==1.14.8
# !pip install -U botocore
# Out:
# Collecting boto3==1.14.8
#   Downloading boto3-1.14.8-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting botocore<1.18.0,>=1.17.8 (from boto3==1.14.8)
#   Downloading botocore-1.17.63-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3==1.14.8)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting s3transfer<0.4.0,>=0.3.0 (from boto3==1.14.8)
#   Downloading s3transfer-0.3.7-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.18.0,>=1.17.8->boto3==1.14.8) (2.9.0.post0)
# Collecting docutils<0.16,>=0.10 (from botocore<1.18.0,>=1.17.8->boto3==1.14.8)
#   Downloading docutils-0.15.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting urllib3<1.26,>=1.20 (from botocore<1.18.0,>=1.17.8->boto3==1.14.8)
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.18.0,>=1.17.8->boto3==1.14.8) (1.17.0)
# Downloading boto3-1.14.8-py2.py3-none-any.whl (128 kB)
# Downloading botocore-1.17.63-py2.py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 108.3 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Downloading s3transfer-0.3.7-py2.py3-none-any.whl (73 kB)
# Downloading docutils-0.15.2-py3-none-any.whl (547 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.6/547.6 kB 53.5 MB/s eta 0:00:00
# Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
# Installing collected packages: urllib3, jmespath, docutils, botocore, s3transfer, boto3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: jmespath
#     Found existing installation: jmespath 1.0.1
#     Uninstalling jmespath-1.0.1:
#       Successfully uninstalled jmespath-1.0.1
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.16
#     Uninstalling docutils-0.16:
#       Successfully uninstalled docutils-0.16
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.37.6
#     Uninstalling botocore-1.37.6:
#       Successfully uninstalled botocore-1.37.6
#   Attempting uninstall: s3transfer
#     Found existing installation: s3transfer 0.11.2
#     Uninstalling s3transfer-0.11.2:
#       Successfully uninstalled s3transfer-0.11.2
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.37.6
#     Uninstalling boto3-1.37.6:
#       Successfully uninstalled boto3-1.37.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pygithub 2.5.0 requires urllib3>=1.26.0, but you have urllib3 1.25.11 which is incompatible.
# awscli 1.38.6 requires botocore==1.37.6, but you have botocore 1.17.63 which is incompatible.
# awscli 1.38.6 requires s3transfer<0.12.0,>=0.11.0, but you have s3transfer 0.3.7 which is incompatible.
# docker 7.1.0 requires urllib3>=1.26.0, but you have urllib3 1.25.11 which is incompatible.
# sagemaker 2.240.0 requires boto3<2.0,>=1.35.75, but you have boto3 1.14.8 which is incompatible.
# sagemaker 2.240.0 requires urllib3<3.0.0,>=1.26.8, but you have urllib3 1.25.11 which is incompatible.
# sagemaker-core 1.0.25 requires boto3<2.0.0,>=1.35.75, but you have boto3 1.14.8 which is incompatible.
# sphinx 8.1.3 requires docutils<0.22,>=0.20, but you have docutils 0.15.2 which is incompatible.
# sphinx 8.1.3 requires packaging>=23.0, but you have packaging 21.3 which is incompatible.
# Successfully installed boto3-1.14.8 botocore-1.17.63 docutils-0.15.2 jmespath-0.10.0 s3transfer-0.3.7 urllib3-1.25.11
# Requirement already satisfied: botocore in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.17.63)
# Collecting botocore
#   Downloading botocore-1.37.12-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore) (1.25.11)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore) (1.17.0)
# Downloading botocore-1.37.12-py3-none-any.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 151.6 MB/s eta 0:00:00
# Installing collected packages: botocore
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.17.63
#     Uninstalling botocore-1.17.63:
#       Successfully uninstalled botocore-1.17.63
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# awscli 1.38.6 requires botocore==1.37.6, but you have botocore 1.37.12 which is incompatible.
# awscli 1.38.6 requires s3transfer<0.12.0,>=0.11.0, but you have s3transfer 0.3.7 which is incompatible.
# boto3 1.14.8 requires botocore<1.18.0,>=1.17.8, but you have botocore 1.37.12 which is incompatible.
# sagemaker 2.240.0 requires boto3<2.0,>=1.35.75, but you have boto3 1.14.8 which is incompatible.
# sagemaker 2.240.0 requires urllib3<3.0.0,>=1.26.8, but you have urllib3 1.25.11 which is incompatible.
# sagemaker-core 1.0.25 requires boto3<2.0.0,>=1.35.75, but you have boto3 1.14.8 which is incompatible.
# Successfully installed botocore-1.37.12

# %%
import boto3
import time
import pprint
import json
import sagemaker
from sagemaker import get_execution_role
from datetime import datetime, timezone

pp = pprint.PrettyPrinter(indent=4)

sagemaker_client = boto3.client("sagemaker")
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pydantic/_internal/_fields.py:192: UserWarning: Field name "json" in "MonitoringDatasetFormat" shadows an attribute in parent "Base"
#   warnings.warn(
# [03/14/25 02:28:28] INFO     Found credentials from IAM Role:                                   ]8;id=313256;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=744623;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# [03/14/25 02:28:31] INFO     Found credentials from IAM Role:                                   ]8;id=526841;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=705230;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole

# %%
BUCKET = "ground-truth-bucket-aa"
EXP_NAME = "test"  # Any valid S3 prefix.

# %%
# Make sure the bucket is in the same region as this notebook.
sess = sagemaker.session.Session()
role = sagemaker.get_execution_role()
region = boto3.session.Session().region_name
s3 = boto3.client("s3")
bucket_region = s3.head_bucket(Bucket=BUCKET)["ResponseMetadata"]["HTTPHeaders"][
    "x-amz-bucket-region"
]
assert (
    bucket_region == region
), "Your S3 bucket {} and this notebook need to be in the same region.".format(BUCKET)

# %% [markdown]
# ## The Dataset and Input Manifest Files

# %% [markdown]
# The dataset and resources used in this notebook are located in the following Amazon S3 bucket: https://aws-ml-blog.s3.amazonaws.com/artifacts/gt-point-cloud-demos/.
#
# This bucket contains a single scene from the [KITTI datasets](http://www.cvlibs.net/datasets/kitti/raw_data.php). KITTI created datasets for computer vision and machine learning research, including for 2D and 3D object detection and object tracking. The datasets are captured by driving around the mid-size city of Karlsruhe, in rural areas and on highways.
#
# \[1\] The KITTI dataset is subject to its own license.  Please make sure that any use of the dataset conforms to the license terms and conditions.

# %% [markdown]
# ## Download and unzip data

# %%
rm -rf sample_data*

# %%
# !wget https://aws-ml-blog.s3.amazonaws.com/artifacts/gt-point-cloud-demos/sample_data.zip
# Out:
# --2025-03-14 02:29:52--  https://aws-ml-blog.s3.amazonaws.com/artifacts/gt-point-cloud-demos/sample_data.zip
# Resolving aws-ml-blog.s3.amazonaws.com (aws-ml-blog.s3.amazonaws.com)... 52.217.195.81, 54.231.139.9, 52.217.228.73, ...
# Connecting to aws-ml-blog.s3.amazonaws.com (aws-ml-blog.s3.amazonaws.com)|52.217.195.81|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 518641729 (495M) [application/zip]
# Saving to: ‘sample_data.zip’
#
# 100%[======================================>] 518,641,729 69.3MB/s   in 8.0s
#
# 2025-03-14 02:30:00 (61.8 MB/s) - ‘sample_data.zip’ saved [518641729/518641729]

# %%
# !unzip -o sample_data
# Out:
# Archive:  sample_data.zip
#    creating: sample_data/
#   inflating: sample_data/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/sample_data/
#   inflating: __MACOSX/sample_data/._.DS_Store
#    creating: sample_data/2011_09_26/
#   inflating: sample_data/2011_09_26/calib_velo_to_cam.txt
#    creating: __MACOSX/sample_data/2011_09_26/
#   inflating: __MACOSX/sample_data/2011_09_26/._calib_velo_to_cam.txt
#   inflating: sample_data/2011_09_26/.DS_Store
#   inflating: __MACOSX/sample_data/2011_09_26/._.DS_Store
#    creating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/.DS_Store
#    creating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/._.DS_Store
#    creating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/timestamps.txt
#    creating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/._timestamps.txt
#    creating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000034.png
#    creating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000034.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000020.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000020.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000008.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000008.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000140.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000140.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000141.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000141.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000009.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000009.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000021.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000021.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000035.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000035.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000023.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000023.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000037.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000037.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000143.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000143.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000142.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000142.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000036.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000036.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000022.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000022.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000026.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000026.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000032.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000032.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000152.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000152.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000146.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000146.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000147.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000147.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000153.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000153.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000033.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000033.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000027.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000027.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000019.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000019.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000031.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000031.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000025.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000025.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000145.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000145.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000151.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000151.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000150.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000150.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000144.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000144.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000024.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000024.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000030.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000030.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000018.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000018.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000094.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000094.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000080.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000080.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000057.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000057.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000043.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000043.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000123.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000123.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000137.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000137.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000136.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000136.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000122.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000122.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000042.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000042.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000056.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000056.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000081.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000081.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000095.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000095.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000083.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000083.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000097.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000097.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000040.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000040.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000054.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000054.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000068.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000068.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000134.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000134.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000120.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000120.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000108.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000108.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000109.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000109.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000121.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000121.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000135.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000135.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000069.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000069.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000055.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000055.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000041.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000041.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000096.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000096.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000082.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000082.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000086.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000086.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000092.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000092.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000079.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000079.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000045.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000045.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000051.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000051.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000119.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000119.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000131.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000131.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000125.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000125.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000124.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000124.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000130.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000130.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000118.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000118.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000050.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000050.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000044.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000044.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000078.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000078.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000093.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000093.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000087.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000087.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000091.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000091.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000085.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000085.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000052.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000052.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000046.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000046.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000126.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000126.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000132.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000132.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000133.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000133.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000127.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000127.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000047.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000047.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000053.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000053.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000084.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000084.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000090.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000090.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000089.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000089.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000076.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000076.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000062.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000062.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000102.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000102.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000116.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000116.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000117.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000117.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000103.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000103.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000063.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000063.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000077.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000077.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000088.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000088.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000061.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000061.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000075.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000075.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000049.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000049.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000115.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000115.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000101.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000101.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000129.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000129.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000128.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000128.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000100.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000100.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000114.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000114.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000048.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000048.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000074.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000074.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000060.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000060.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000058.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000058.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000064.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000064.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000070.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000070.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000138.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000138.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000110.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000110.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000104.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000104.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000105.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000105.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000111.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000111.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000139.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000139.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000071.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000071.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000065.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000065.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000059.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000059.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000098.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000098.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000073.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000073.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000067.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000067.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000107.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000107.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000113.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000113.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000112.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000112.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000106.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000106.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000066.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000066.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000072.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000072.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000099.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000099.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000015.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000015.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000001.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000001.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000029.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000029.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000149.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000149.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000148.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000148.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000028.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000028.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000000.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000000.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000014.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000014.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000002.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000002.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000016.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000016.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000017.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000017.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000003.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000003.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000007.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000007.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000013.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000013.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000012.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000012.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000006.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000006.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000038.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000038.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000010.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000010.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000004.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000004.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000005.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000005.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000011.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000011.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/0000000039.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/data/._0000000039.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_03/._data
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/._image_03
#    creating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/timestamps.txt
#    creating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/._timestamps.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/dataformat.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/._dataformat.txt
#    creating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000122.txt
#    creating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000122.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000136.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000136.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000056.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000056.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000042.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000042.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000095.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000095.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000081.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000081.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000080.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000080.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000094.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000094.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000043.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000043.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000057.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000057.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000137.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000137.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000123.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000123.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000109.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000109.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000135.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000135.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000121.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000121.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000069.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000069.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000041.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000041.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000055.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000055.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000082.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000082.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000096.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000096.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000097.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000097.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000083.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000083.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000054.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000054.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000040.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000040.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000068.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000068.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000120.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000120.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000134.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000134.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000108.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000108.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000130.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000130.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000124.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000124.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000118.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000118.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000044.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000044.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000050.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000050.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000078.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000078.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000087.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000087.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000093.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000093.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000092.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000092.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000086.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000086.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000079.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000079.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000051.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000051.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000045.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000045.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000119.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000119.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000125.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000125.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000131.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000131.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000127.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000127.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000133.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000133.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000053.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000053.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000047.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000047.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000090.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000090.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000084.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000084.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000085.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000085.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000091.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000091.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000046.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000046.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000052.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000052.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000132.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000132.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000126.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000126.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000141.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000141.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000009.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000009.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000035.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000035.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000021.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000021.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000020.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000020.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000034.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000034.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000008.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000008.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000140.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000140.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000142.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000142.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000022.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000022.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000036.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000036.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000037.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000037.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000023.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000023.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000143.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000143.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000153.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000153.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000147.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000147.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000027.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000027.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000033.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000033.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000032.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000032.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000026.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000026.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000146.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000146.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000152.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000152.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000144.txt
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/._0000000144.txt
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data/0000000150.txt
# ...
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000091.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000085.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000085.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000052.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000052.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000046.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000046.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000126.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000126.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000132.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000132.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000133.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000133.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000127.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000127.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000047.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000047.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000053.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000053.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000084.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000084.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000090.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000090.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000089.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000089.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000076.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000076.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000062.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000062.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000102.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000102.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000116.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000116.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000117.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000117.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000103.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000103.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000063.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000063.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000077.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000077.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000088.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000088.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000061.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000061.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000075.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000075.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000049.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000049.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000115.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000115.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000101.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000101.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000129.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000129.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000128.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000128.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000100.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000100.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000114.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000114.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000048.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000048.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000074.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000074.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000060.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000060.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000058.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000058.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000064.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000064.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000070.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000070.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000138.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000138.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000110.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000110.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000104.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000104.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000105.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000105.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000111.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000111.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000139.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000139.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000071.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000071.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000065.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000065.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000059.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000059.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000098.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000098.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000073.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000073.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000067.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000067.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000107.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000107.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000113.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000113.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000112.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000112.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000106.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000106.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000066.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000066.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000072.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000072.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000099.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000099.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000015.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000015.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000001.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000001.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000029.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000029.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000149.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000149.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000148.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000148.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000028.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000028.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000000.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000000.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000014.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000014.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000002.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000002.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000016.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000016.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000017.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000017.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000003.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000003.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000007.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000007.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000013.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000013.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000012.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000012.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000006.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000006.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000038.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000038.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000010.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000010.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000004.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000004.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000005.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000005.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000011.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000011.png
#   inflating: sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/0000000039.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/data/._0000000039.png
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/image_01/._data
#   inflating: __MACOSX/sample_data/2011_09_26/2011_09_26_drive_0005_sync/._image_01
#   inflating: __MACOSX/sample_data/2011_09_26/._2011_09_26_drive_0005_sync
#   inflating: sample_data/2011_09_26/calib_imu_to_velo.txt
#   inflating: __MACOSX/sample_data/2011_09_26/._calib_imu_to_velo.txt
#   inflating: sample_data/2011_09_26/calib_cam_to_cam.txt
#   inflating: __MACOSX/sample_data/2011_09_26/._calib_cam_to_cam.txt
#   inflating: __MACOSX/sample_data/._2011_09_26

# %% [markdown]
# Let's take a look at the sample_data folder. You'll see that we have images which can be used for sensor fusion, and point cloud data in ASCII format (.txt files). We will use a script to convert this point cloud data from the LiDAR sensor's local coordinates to a world coordinate system.

# %%
# !ls sample_data/2011_09_26/2011_09_26_drive_0005_sync/
# Out:
# image_00  image_01  image_02  image_03	oxts  velodyne_points

# %%
# !ls sample_data/2011_09_26/2011_09_26_drive_0005_sync/oxts/data
# Out:
# 0000000000.txt	0000000031.txt	0000000062.txt	0000000093.txt	0000000124.txt
# 0000000001.txt	0000000032.txt	0000000063.txt	0000000094.txt	0000000125.txt
# 0000000002.txt	0000000033.txt	0000000064.txt	0000000095.txt	0000000126.txt
# 0000000003.txt	0000000034.txt	0000000065.txt	0000000096.txt	0000000127.txt
# 0000000004.txt	0000000035.txt	0000000066.txt	0000000097.txt	0000000128.txt
# 0000000005.txt	0000000036.txt	0000000067.txt	0000000098.txt	0000000129.txt
# 0000000006.txt	0000000037.txt	0000000068.txt	0000000099.txt	0000000130.txt
# 0000000007.txt	0000000038.txt	0000000069.txt	0000000100.txt	0000000131.txt
# 0000000008.txt	0000000039.txt	0000000070.txt	0000000101.txt	0000000132.txt
# 0000000009.txt	0000000040.txt	0000000071.txt	0000000102.txt	0000000133.txt
# 0000000010.txt	0000000041.txt	0000000072.txt	0000000103.txt	0000000134.txt
# 0000000011.txt	0000000042.txt	0000000073.txt	0000000104.txt	0000000135.txt
# 0000000012.txt	0000000043.txt	0000000074.txt	0000000105.txt	0000000136.txt
# 0000000013.txt	0000000044.txt	0000000075.txt	0000000106.txt	0000000137.txt
# 0000000014.txt	0000000045.txt	0000000076.txt	0000000107.txt	0000000138.txt
# 0000000015.txt	0000000046.txt	0000000077.txt	0000000108.txt	0000000139.txt
# 0000000016.txt	0000000047.txt	0000000078.txt	0000000109.txt	0000000140.txt
# 0000000017.txt	0000000048.txt	0000000079.txt	0000000110.txt	0000000141.txt
# 0000000018.txt	0000000049.txt	0000000080.txt	0000000111.txt	0000000142.txt
# 0000000019.txt	0000000050.txt	0000000081.txt	0000000112.txt	0000000143.txt
# 0000000020.txt	0000000051.txt	0000000082.txt	0000000113.txt	0000000144.txt
# 0000000021.txt	0000000052.txt	0000000083.txt	0000000114.txt	0000000145.txt
# 0000000022.txt	0000000053.txt	0000000084.txt	0000000115.txt	0000000146.txt
# 0000000023.txt	0000000054.txt	0000000085.txt	0000000116.txt	0000000147.txt
# 0000000024.txt	0000000055.txt	0000000086.txt	0000000117.txt	0000000148.txt
# 0000000025.txt	0000000056.txt	0000000087.txt	0000000118.txt	0000000149.txt
# 0000000026.txt	0000000057.txt	0000000088.txt	0000000119.txt	0000000150.txt
# 0000000027.txt	0000000058.txt	0000000089.txt	0000000120.txt	0000000151.txt
# 0000000028.txt	0000000059.txt	0000000090.txt	0000000121.txt	0000000152.txt
# 0000000029.txt	0000000060.txt	0000000091.txt	0000000122.txt	0000000153.txt
# 0000000030.txt	0000000061.txt	0000000092.txt	0000000123.txt

# %% [markdown]
# ## Use the Kitti2GT script to convert the raw data to Ground Truth format
#
# You can use this script to do the following:
# * Transform the KITTI dataset with respect to the LIDAR sensor's orgin in the first frame as the world cooridinate system ( global frame of reference ), so that it can be consumed by SageMaker Ground Truth.
# * Extract pose data in world coordinate system using the camera and LiDAR extrinsic matrices. You will supply this pose data in your sequence file to enable sensor fusion.
#
# First, the script uses [pykitti](https://github.com/utiasSTARS/pykitti) python module to load the KITTI raw data and calibrations. Let's look at the two main data-transformation functions of the script:
#
# ### Data Transformation to a World Coordinate System
#
# In general, multiplying a point in a LIDAR frame with a LIDAR extrinsic matrix transforms it into world coordinates.
#
# Using pykitti `dataset.oxts[i].T_w_imu` gives the lidar extrinsic transform for the `i`th frame. This matrix can be multiplied with the points of the frame to convert it to a world frame using the numpy matrix multiplication, function, [matmul](https://numpy.org/doc/1.18/reference/generated/numpy.matmul.html): `matmul(lidar_transform_matrix, points)`. Let's look at the function that performs this transformation:

# %%
# transform points from lidar to global frame using lidar_extrinsic_matrix
def generate_transformed_pcd_from_point_cloud(points, lidar_extrinsic_matrix):
    tps = []
    for point in points:
        transformed_points = np.matmul(
            lidar_extrinsic_matrix,
            np.array([point[0], point[1], point[2], 1], dtype=np.float32).reshape(4, 1),
        ).tolist()
        if len(point) > 3 and point[3] is not None:
            tps.append(
                [
                    transformed_points[0][0],
                    transformed_points[1][0],
                    transformed_points[2][0],
                    point[3],
                ]
            )

    return tps

# %% [markdown]
# If your point cloud data includes more than four elements for each point, for example, (x,y,z) and r,g,b, modify the `if` statement in the function above to ensure your r, g, b values are copied.

# %% [markdown]
# ### Extracting Pose Data from LiDAR and Camera Extrinsic for Sensor Fusion
#
#
# For sensor fusion, you provide your extrinsic matrix in the form of sensor-pose in terms of origin position (for translation) and heading in quaternion (for rotation of the 3 axis). The following is an example of the pose JSON you use in the sequence file.
#
# ```
#
# {
#     "position": {
#         "y": -152.77584902657554,
#         "x": 311.21505956090624,
#         "z": -10.854137529636024
#       },
#       "heading": {
#         "qy": -0.7046155108831117,
#         "qx": 0.034278837280808494,
#         "qz": 0.7070617895701465,
#         "qw": -0.04904659893885366
#       }
# }
# ```
#
# All of the positional coordinates (x, y, z) are in meters. All the pose headings (qx, qy, qz, qw) are measured in Spatial Orientation in Quaternion. Separately for each camera, you provide pose data extracted from the extrinsic of that camera.
#
# Both LIDAR sensors and and cameras have their own extrinsic matrices, and they are used by SageMaker Ground Truth to enable the sensor fusion feature. In order to project a label from 3D point cloud to camera image plane Ground Truth needs to transform 3D points from LIDAR’s own coordinate system to the camera’s coordinate system. This is typically done by first transforming 3D points from LIDAR’s own coordinate to a world coordinate system using the LIDAR extrinsic matrix. Then we use the camera inverse extrinsic (world to camera) to transform the 3D points from the world coordinate system we obtained in previous step into camera image plane. If your 3D data is already transformed into world coordinate system then the first transformation doesn’t have any impact and label translation depends only on the camera extrinsic.
#
# If you have a rotation matrix (made up of the axis rotations) and translation vector (or origin) in world coordinate system instead of a single 4x4 rigid transformation matrix, then you can directly use rotation and translation to compute pose. For example:

# %%
# !python -m pip install --user numpy scipy
# Out:
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.15.1)

# %%
import numpy as np

rotation = [
    [9.96714314e-01, -8.09890350e-02, 1.16333982e-03],
    [8.09967396e-02, 9.96661051e-01, -1.03090934e-02],
    [-3.24531964e-04, 1.03694477e-02, 9.99946183e-01],
]

origin = [1.71104606e00, 5.80000039e-01, 9.43144935e-01]


from scipy.spatial.transform import Rotation as R

# position is the origin
position = origin
r = R.from_matrix(np.asarray(rotation))
# heading in WCS using scipy
heading = r.as_quat()
print(f"position:{position}\nheading: {heading}")
# Out:
# position:[1.71104606, 0.580000039, 0.943144935]
# heading: [5.17395633e-03 3.72278857e-04 4.05302927e-02 9.99164845e-01]

# %% [markdown]
# If you indeed have a 4x4 extrinsic transformation matrix then the transformation matrix is just in the form of ```[R T; 0 0 0 1]``` where R is the rotation matrix and T is the origin translation vector. That means you can extract rotation matrix and translation vector from the transformation matrix as follows

# %%
import numpy as np

transformation = [
    [9.96714314e-01, -8.09890350e-02, 1.16333982e-03, 1.71104606e00],
    [8.09967396e-02, 9.96661051e-01, -1.03090934e-02, 5.80000039e-01],
    [-3.24531964e-04, 1.03694477e-02, 9.99946183e-01, 9.43144935e-01],
    [0, 0, 0, 1],
]

transformation = np.array(transformation)
rotation = transformation[0:3, 0:3]
origin = transformation[0:3, 3]

from scipy.spatial.transform import Rotation as R

# position is the origin
position = origin
r = R.from_matrix(np.asarray(rotation))
# heading in WCS using scipy
heading = r.as_quat()
print(f"position:{position}\nheading: {heading}")
# Out:
# position:[1.71104606 0.58000004 0.94314493]
# heading: [5.17395633e-03 3.72278857e-04 4.05302927e-02 9.99164845e-01]

# %% [markdown]
# For convenience, in this blog you will use [pykitti](https://github.com/utiasSTARS/pykitti) development kit to load the raw data and calibrations. With pykitti you will extract sensor pose in the world coordinate system from KITTI extrinsic which is provided as a rotation matrix and translation vector in the raw calibrations data. We will then format this pose data using the JSON format required for the 3D point cloud sequence input manifest.
#
# With pykitti the ```dataset.oxts[i].T_w_imu``` gives the LiDAR extrinsic matrix ( lidar_extrinsic_transform ) for the i'th frame. Similarly, with pykitti the camera extrinsic matrix ( camera_extrinsic_transform  ) for cam0 in i'th frame can be calculated by ```inv(matmul(dataset.calib.T_cam0_velo, inv(dataset.oxts[i].T_w_imu)))``` and this can be converted into heading and position for cam0.
#
# In the script, the following functions are used to extract this pose data from the LiDAR extrinsict and camera inverse extrinsic matrices.

# %%
# utility to convert extrinsic matrix to pose heading quaternion and position
def convert_extrinsic_matrix_to_trans_quaternion_mat(lidar_extrinsic_transform):
    position = lidar_extrinsic_transform[0:3, 3]
    rot = np.linalg.inv(lidar_extrinsic_transform[0:3, 0:3])
    quaternion = R.from_matrix(np.asarray(rot)).as_quat()
    trans_quaternions = {
        "translation": {"x": position[0], "y": position[1], "z": position[2]},
        "rotation": {
            "qx": quaternion[0],
            "qy": quaternion[1],
            "qz": quaternion[2],
            "qw": quaternion[3],
        },
    }
    return trans_quaternions


def convert_camera_inv_extrinsic_matrix_to_trans_quaternion_mat(camera_extrinsic_transform):
    position = camera_extrinsic_transform[0:3, 3]
    rot = np.linalg.inv(camera_extrinsic_transform[0:3, 0:3])
    quaternion = R.from_matrix(np.asarray(rot)).as_quat()
    trans_quaternions = {
        "translation": {"x": position[0], "y": position[1], "z": position[2]},
        "rotation": {
            "qx": quaternion[0],
            "qy": quaternion[1],
            "qz": quaternion[2],
            "qw": -quaternion[3],
        },
    }
    return trans_quaternions

# %% [markdown]
# ### Generate a Sequence File
#
#
# After you've converted your data to a world coordinate system and extracted sensor and camera pose data for sensor fusion, you can create a sequence file. This is accomplished with the function `convert_to_gt` in the python script.
#
# A **sequence** specifies a temporal series of point cloud frames. When a task is created using a sequence file, all point cloud frames in the sequence are sent to a worker to label. Your input manifest file will contain a single sequence per line. To learn more about the sequence input manifest format, see [Create a Point Cloud Frame Sequence Input Manifest](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-point-cloud-multi-frame-input-data.html).
#
#
# If you want to use this script to create a frame input manifest file, which is required for 3D point cloud object tracking and semantic segmentation labeling jobs, you can modify the for-loop in the function `convert_to_gt`
# to produce the required content for `source-ref-metadata`. To learn more about the frame input manifest format, see [Create a Point Cloud Frame Input Manifest File](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-point-cloud-single-frame-input-data.html).

# %% [markdown]
# Now, let's download the script and run it on the KITTI dataset to process the data you'll use for your labeling job.

# %%
# !wget https://aws-ml-blog.s3.amazonaws.com/artifacts/gt-point-cloud-demos/kitti2gt.py
# Out:
# --2025-03-14 02:35:47--  https://aws-ml-blog.s3.amazonaws.com/artifacts/gt-point-cloud-demos/kitti2gt.py
# Resolving aws-ml-blog.s3.amazonaws.com (aws-ml-blog.s3.amazonaws.com)... 52.217.48.244, 16.15.176.88, 16.182.33.137, ...
# Connecting to aws-ml-blog.s3.amazonaws.com (aws-ml-blog.s3.amazonaws.com)|52.217.48.244|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6135 (6.0K) [text/x-python]
# Saving to: ‘kitti2gt.py’
#
# 100%[======================================>] 6,135       --.-K/s   in 0s
#
# 2025-03-14 02:35:47 (201 MB/s) - ‘kitti2gt.py’ saved [6135/6135]

# %%
# !pygmentize kitti2gt.py
# Out:
# import pykitti
# import numpy as np
# import csv, json, os
# from datetime import timezone
# from shutil import copyfile
# from scipy.spatial.transform import Rotation as R
#
# # transform points from lidar to global frame using lidar_extrinsic_matrix
# def generate_transformed_pcd_from_point_cloud(points, lidar_extrinsic_matrix):
#     tps = []
#     for point in points:
#         transformed_points = np.matmul(lidar_extrinsic_matrix, np.array([point[0], point[1], point[2], 1], dtype=np.float32).reshape(4,1)).tolist()
#         if len(point) > 3 and point[3] is not None:
#             tps.append([transformed_points[0][0], transformed_points[1][0], transformed_points[2][0], point[3]])
#
#     return tps
#
# # utility to convert extrinsic matrix to pose heading quaternion and position
# def convert_extrinsic_matrix_to_trans_quaternion_mat(inp_ext_mat):
#     position = inp_ext_mat[0:3, 3]
#     rot = np.linalg.inv(inp_ext_mat[0:3, 0:3])
#     quaternion= R.from_matrix(np.asarray(rot)).as_quat()
#     trans_quaternions = {
#         "translation": {
#             "x": position[0],
#             "y": position[1],
#             "z": position[2]
#         },
#         "rotation": {
#             "qx": quaternion[0],
#             "qy": quaternion[1],
#             "qz": quaternion[2],
#             "qw": quaternion[3]
#             }
#     }
#     return trans_quaternions
#
# def convert_camera_inv_extrinsic_matrix_to_trans_quaternion_mat(inp_ext_mat):
#     position = inp_ext_mat[0:3, 3]
#     rot = np.linalg.inv(inp_ext_mat[0:3, 0:3])
#     quaternion= R.from_matrix(np.asarray(rot)).as_quat()
#     trans_quaternions = {
#         "translation": {
#             "x": position[0],
#             "y": position[1],
#             "z": position[2]
#         },
#         "rotation": {
#             "qx": quaternion[0],
#             "qy": quaternion[1],
#             "qz": quaternion[2],
#             "qw": -quaternion[3]
#             }
#     }
#     return trans_quaternions
#
#
# # assuming you downloaded kitti raw data in this dir from http://www.cvlibs.net/datasets/kitti/raw_data.php
# # basedir = '/Users/username/Downloads/kitti-data'
# # # use a given date in the datase
# # date = '2011_09_26'
# # # use a given drive
# # drive = '0079'
# # output_base = '/Users/username/Downloads/mykitti-new'
#
# def convert_to_gt(basedir,date,drive,output_base,s3prefix):
#
# 	if not os.path.exists(output_base):
# 		os.makedirs(output_base+'/frames/')
#     # The 'frames' argument is optional - default: None, which loads the whole dataset.
# 	# Calibration, timestamps, and IMU data are read automatically.
# 	# Camera and velodyne data are available via properties that create generators
# 	# when accessed, or through getter methods that provide random access.
# 	data = pykitti.raw(basedir, date, drive, frames=range(0, 50, 5))
# 	image_paths  = [data.cam0_files,  data.cam1_files, data.cam2_files, data.cam3_files]
# 	camera_extrinsic_calibrations = [data.calib.T_cam0_velo, data.calib.T_cam1_velo, data.calib.T_cam2_velo, data.calib.T_cam3_velo]
# 	camera_intrinsics = [data.calib.K_cam0, data.calib.K_cam1, data.calib.K_cam2, data.calib.K_cam3]
# 	seq_json = {}
# 	seq_json["seq-no"] = 1
# 	seq_json["prefix"] = s3prefix
# 	seq_json["number-of-frames"] = len(data)
# 	seq_json["frames"] = []
# 	default_position = {"x": 0, "y": 0, "z": 0}
# 	default_heading = {"qx": 0, "qy": 0, "qz": 0, "qw": 1}
# 	for i in range(len(data)):
# 		# customer computes lidar extrinsics
# 		lidar_extrinsic_matrix = data.oxts[i].T_w_imu
# 		# velodyne raw point cloud in lidar scanners own coordinate system
# 		points = data.get_velo(i)
# 		# customer transforms points from lidar to global frame using lidar_extrinsic_matrix
# 		transformed_pcl = generate_transformed_pcd_from_point_cloud(points, lidar_extrinsic_matrix)
# 		# Customer computes rotation quaternion and translation from LiDAR Extrinsic
# 		trans_quaternions = convert_extrinsic_matrix_to_trans_quaternion_mat(lidar_extrinsic_matrix)
# 		# Customer uses trans_quaternions to populates GT ego veicle pose
# 		ego_vehicle_pose = {}
# 		ego_vehicle_pose['heading'] = trans_quaternions['rotation']
# 		ego_vehicle_pose['position'] = trans_quaternions['translation']
# 		# open file to write the transformed pcl
# 		with open(output_base+"/frames/"+str(i)+'.txt', "w") as out:
# 			writer = csv.writer(out, delimiter=' ', quotechar='"', quoting=csv.QUOTE_MINIMAL)
# 			for point in transformed_pcl:
# 				writer.writerow((point[0], point[1], point[2], point[3]))
# 		frame = {}
# 		frame["frame-no"] = i
# 		frame["frame"] = str(i)+'.txt'
# 		frame["unix-timestamp"] = data.timestamps[i].replace(tzinfo=timezone.utc).timestamp()
# 		frame["ego-vehicle-pose"] = ego_vehicle_pose
# 		images = []
# 		image_dir_path = os.path.join(output_base, 'images')
# 		if not os.path.exists(image_dir_path):
# 			os.makedirs(image_dir_path)
# 		for j in range(len(image_paths)):
# 			# copy image
# 			image_path = image_paths[j][i]
# 			image_suffix_path = 'images/frame_'+str(i)+'_camera_'+str(j)+'.jpg'
# 			copyfile(image_path, os.path.join(output_base, image_suffix_path))
# 			# If customer has the camera extrinsics then they use them to compute the camera transform
# 			camera_transform= np.linalg.inv(np.matmul(camera_extrinsic_calibrations[j], np.linalg.inv(data.oxts[i].T_w_imu)))
# 			# Customer computes rotation quaternion and translation from camera inverse Extrinsic
# 			cam_trans_quaternions = convert_camera_inv_extrinsic_matrix_to_trans_quaternion_mat(camera_transform)
# 			image_json = {}
# 			image_json["image-path"] = image_suffix_path
# 			image_json["unix-timestamp"] = frame["unix-timestamp"]
# 			image_json['heading'] = cam_trans_quaternions['rotation']
# 			image_json['position'] = cam_trans_quaternions['translation']
# 			image_json['fx'] = camera_intrinsics[j][0][0]
# 			image_json['fy'] = camera_intrinsics[j][1][1]
# 			image_json['cx'] = camera_intrinsics[j][0][2]
# 			image_json['cy'] = camera_intrinsics[j][1][2]
# 			image_json['k1'] = 0
# 			image_json['k2'] = 0
# 			image_json['k3'] = 0
# 			image_json['k4'] = 0
# 			image_json['p1'] = 0
# 			image_json['p2'] = 0
# 			image_json['skew'] = 0
# 			images.append(image_json)
# 		frame["images"]=images
# 		seq_json["frames"].append(frame)
# 	with open(output_base+'/kitti-gt-seq.json', 'w') as outfile:
# 		json.dump(seq_json, outfile)

# %% [markdown]
# ### Install pykitti

# %%
# !pip install pykitti
# Out:
# Collecting pykitti
#   Downloading pykitti-0.3.1-py2.py3-none-any.whl.metadata (449 bytes)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pykitti) (1.26.4)
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pykitti) (3.10.0)
# Requirement already satisfied: Pillow in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pykitti) (11.1.0)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pykitti) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pykitti) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pykitti) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pykitti) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pykitti) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pykitti) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pykitti) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->pykitti) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas->pykitti) (2025.1)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->pykitti) (1.17.0)
# Downloading pykitti-0.3.1-py2.py3-none-any.whl (13 kB)
# Installing collected packages: pykitti
# Successfully installed pykitti-0.3.1

# %%
# !pip install cv2
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
from kitti2gt import *

if EXP_NAME == "":
    s3loc = f"s3://{BUCKET}/frames/"
else:
    s3loc = f"s3://{BUCKET}/{EXP_NAME}/frames/"

convert_to_gt(
    basedir="sample_data",
    date="2011_09_26",
    drive="0005",
    output_base="sample_data_out",
    s3prefix=s3loc,
)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱  1 from kitti2gt import *                                                                      │
# │    2                                                                                             │
# │    3 if EXP_NAME == "":                                                                          │
# │    4 │   s3loc = f"s3://{BUCKET}/frames/"                                                        │
# │                                                                                                  │
# │ /home/ec2-user/SageMaker/3d_point_cloud_input_data_processing_2025-03-14/kitti2gt.py:1 in        │
# │ <module>                                                                                         │
# │                                                                                                  │
# │ ❱   1 import pykitti                                                                             │
# │     2 import numpy as np                                                                         │
# │     3 import csv, json, os                                                                       │
# │     4 from datetime import timezone                                                              │
# │                                                                                                  │
# │ /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pykitti/__init__.py:5 in      │
# │ <module>                                                                                         │
# │                                                                                                  │
# │   2                                                                                              │
# │   3 from pykitti.odometry import odometry                                                        │
# │   4 from pykitti.raw import raw                                                                  │
# │ ❱ 5 from pykitti.tracking import tracking                                                        │
# │   6                                                                                              │
# │   7 __author__ = "Lee Clement"                                                                   │
# │   8 __email__ = "lee.clement@robotics.utias.utoronto.ca"                                         │
# │                                                                                                  │
# │ /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pykitti/tracking.py:12 in     │
# │ <module>                                                                                         │
# │                                                                                                  │
# │     9 import numpy as np                                                                         │
# │    10                                                                                            │
# │    11 import pykitti.utils as utils                                                              │
# │ ❱  12 import cv2                                                                                 │
# │    13                                                                                            │
# │    14 try:                                                                                       │
# │    15 │   xrange                                                                                 │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# The following folders that will contain the data you'll use for the labeling job.

# %%
# !ls sample_data_out/
# Out:
# ls: cannot access sample_data_out/: No such file or directory

# %%
# !ls sample_data_out/frames
# Out:
# ls: cannot access sample_data_out/frames: No such file or directory

# %% [markdown]
# Now, you'll upload the data to your bucket in S3.

# %%
if(EXP_NAME == ''):
    # !aws s3 cp sample_data_out/kitti-gt-seq.json s3://{BUCKET}/
else:
    # !aws s3 cp sample_data_out/kitti-gt-seq.json s3://{BUCKET}/{EXP_NAME}/
# Out:
# The user-provided path sample_data_out/kitti-gt-seq.json does not exist.

# %%
if(EXP_NAME == ''):
    # !aws s3 sync sample_data_out/frames/ s3://{BUCKET}/frames/
else:
    # !aws s3 sync sample_data_out/frames s3://{BUCKET}/{EXP_NAME}/frames/
# Out:
# The user-provided path sample_data_out/frames does not exist.

# %%
if(EXP_NAME == ''):
    # !aws s3 sync sample_data_out/images/ s3://{BUCKET}/frames/images/
else:
    # !aws s3 sync sample_data_out/images s3://{BUCKET}/{EXP_NAME}/frames/images/
# Out:
# The user-provided path sample_data_out/images does not exist.

# %% [markdown]
# ### Write and Upload Multi-Frame Input Manifest File
#
# Now, let's create a **sequence input manifest file**. Each line in the input manifest (in this demo, there is only one) will point to a sequence file in your S3 bucket, `BUCKET/EXP_NAME`.

# %%
with open("manifest.json", "w") as f:
    if EXP_NAME == "":
        json.dump({"source-ref": "s3://{}/kitti-gt-seq.json".format(BUCKET)}, f)
    else:
        json.dump({"source-ref": "s3://{}/{}/kitti-gt-seq.json".format(BUCKET, EXP_NAME)}, f)

# %% [markdown]
# Our manifest file is one line long, and identifies a single sequence file in your S3 bucket.

# %%
# !cat manifest.json
# Out:
# {"source-ref": "s3://ground-truth-bucket-aa/test/kitti-gt-seq.json"}

# %%
if(EXP_NAME == ''):
    # !aws s3 cp manifest.json s3://{BUCKET}/
    input_manifest_s3uri = f's3://{BUCKET}/manifest.json'
else:
    # !aws s3 cp manifest.json s3://{BUCKET}/{EXP_NAME}/
    input_manifest_s3uri = f's3://{BUCKET}/{EXP_NAME}/manifest.json'
input_manifest_s3uri
# Out:
# upload: ./manifest.json to s3://ground-truth-bucket-aa/test/manifest.json
# 's3://ground-truth-bucket-aa/test/manifest.json'

# %% [markdown]
# ## Create a Labeling Job

# %% [markdown]
# In the following cell, we specify object tracking as our [3D Point Cloud Task Type](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-point-cloud-task-types.html).

# %%
task_type = "3DPointCloudObjectTracking"

# %% [markdown]
# ## Identify Resources for Labeling Job

# %% [markdown]
# ### Specify Human Task UI ARN

# %% [markdown]
# The following will be used to identify the HumanTaskUiArn. When you create a 3D point cloud labeling job, Ground Truth provides a worker UI that is specific to your task type. You can learn more about this UI and the assistive labeling tools that Ground Truth provides for Object Tracking on the [Object Tracking task type page](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-point-cloud-object-tracking.html).

# %%
## Set up human_task_ui_arn map, to be used in case you chose UI_CONFIG_USE_TASK_UI_ARN
## Supported for GA
## Set up human_task_ui_arn map, to be used in case you chose UI_CONFIG_USE_TASK_UI_ARN
human_task_ui_arn = (
    f"arn:aws:sagemaker:{region}:394669845002:human-task-ui/PointCloudObjectTracking"
)
human_task_ui_arn
# Out:
# 'arn:aws:sagemaker:us-east-2:394669845002:human-task-ui/PointCloudObjectTracking'

# %% [markdown]
# ### Label Category Configuration File
#
# Your label category configuration file is used to specify labels, or classes, for your labeling job.
#
# When you use the object detection or object tracking task types, you can also include **label attributes** in your [label category configuration file](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-point-cloud-label-category-config.html). Workers can assign one or more attributes you provide to annotations to give more information about that object. For example, you may want to use the attribute *occluded* to have workers identify when an object is partially obstructed.
#
# Let's look at an example of the label category configuration file for an object detection or object tracking labeling job.

# %%
# !wget https://aws-ml-blog.s3.amazonaws.com/artifacts/gt-point-cloud-demos/label-category-config/label-category.json
# Out:
# --2025-03-14 02:38:15--  https://aws-ml-blog.s3.amazonaws.com/artifacts/gt-point-cloud-demos/label-category-config/label-category.json
# Resolving aws-ml-blog.s3.amazonaws.com (aws-ml-blog.s3.amazonaws.com)... 52.217.81.68, 54.231.236.241, 16.15.217.183, ...
# connected. to aws-ml-blog.s3.amazonaws.com (aws-ml-blog.s3.amazonaws.com)|52.217.81.68|:443...
# 200 OKequest sent, awaiting response...
# Length: 927 [application/json]
# Saving to: ‘label-category.json’
#
# 100%[======================================>] 927         --.-K/s   in 0s
#
# 2025-03-14 02:38:15 (27.3 MB/s) - ‘label-category.json’ saved [927/927]

# %%
with open("label-category.json", "r") as j:
    json_data = json.load(j)
    print(
        "\nA label category configuration file: \n\n",
        json.dumps(json_data, indent=4, sort_keys=True),
    )
# Out:
# A label category configuration file:
#
#  {
#     "categoryGlobalAttributes": [
#         {
#             "description": "global attribute that applies to all label categories",
#             "enum": [
#                 "Partial",
#                 "Full"
#             ],
#             "name": "Occlusion",
#             "type": "string"
#         }
#     ],
#     "document-version": "2020-03-01",
#     "instructions": {
#         "fullInstruction": "Use this area to add more detailed worker instructions.",
#         "shortInstruction": "Draw a tight cuboid around objects after you select a category."
#     },
#     "labels": [
#         {
#             "attributes": [
#                 {
#                     "enum": [
#                         "SUV",
#                         "Sedan"
#                     ],
#                     "name": "Type",
#                     "type": "string"
#                 }
#             ],
#             "label": "Car"
#         },
#         {
#             "attributes": [
#                 {
#                     "enum": [
#                         "Large",
#                         "Medium",
#                         "Small"
#                     ],
#                     "name": "Size",
#                     "type": "string"
#                 }
#             ],
#             "label": "Bus"
#         },
#         {
#             "attributes": [
#                 {
#                     "enum": [
#                         "Large",
#                         "Medium",
#                         "Small"
#                     ],
#                     "name": "Size",
#                     "type": "string"
#                 }
#             ],
#             "label": "Van"
#         },
#         {
#             "label": "Streetcar"
#         },
#         {
#             "attributes": [
#                 {
#                     "enum": [
#                         "Street",
#                         "Highway",
#                         "Bike Lane"
#                     ],
#                     "name": "Color",
#                     "type": "string"
#                 }
#             ],
#             "label": "Road"
#         },
#         {
#             "label": "Bench"
#         },
#         {
#             "label": "Cyclist"
#         },
#         {
#             "attributes": [
#                 {
#                     "enum": [
#                         "Man",
#                         "Women"
#                     ],
#                     "name": "Occlusion",
#                     "type": "string"
#                 }
#             ],
#             "label": "Pedestrian"
#         }
#     ]
# }

# %%
if(EXP_NAME == ''):
    # !aws s3 cp label-category.json s3://{BUCKET}/label-category.json
    label_category_config_s3uri = f's3://{BUCKET}/label-category.json'
else:
    # !aws s3 cp label-category.json s3://{BUCKET}/{EXP_NAME}/label-category.json
    label_category_config_s3uri = f's3://{BUCKET}/{EXP_NAME}/label-category.json'
label_category_config_s3uri
# Out:
# upload: ./label-category.json to s3://ground-truth-bucket-aa/test/label-category.json
# 's3://ground-truth-bucket-aa/test/label-category.json'

# %% [markdown]
# To learn more about the label category configuration file, see [Create a Label Category Configuration File](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-point-cloud-label-category-config.html)
#
# Run the following cell to identify the labeling category configuration file.

# %% [markdown]
# ### Set up a private work team
#
# If you want to preview the worker task UI, create a private work team and add yourself as a worker.
#
# If you have already created a private workforce, follow the instructions in [Add or Remove Workers](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-workforce-management-private-console.html#add-remove-workers-sm) to add yourself to the work team you use to create a lableing job.
#
# #### Create a private workforce and add yourself as a worker
#
# To create and manage your private workforce, you can use the **Labeling workforces** page in the Amazon SageMaker console. When following the instructions below, you will have the option to create a private workforce by entering worker emails or importing a pre-existing workforce from an Amazon Cognito user pool. To import a workforce, see [Create a Private Workforce (Amazon Cognito Console)](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-workforce-create-private-cognito.html).
#
# To create a private workforce using worker emails:
#
# * Open the Amazon SageMaker console at https://console.aws.amazon.com/sagemaker/.
#
# * In the navigation pane, choose **Labeling workforces**.
#
# * Choose Private, then choose **Create private team**.
#
# * Choose **Invite new workers by email**.
#
# * Paste or type a list of up to 50 email addresses, separated by commas, into the email addresses box.
#
# * Enter an organization name and contact email.
#
# * Optionally choose an SNS topic to subscribe the team to so workers are notified by email when new Ground Truth labeling jobs become available.
#
# * Click the **Create private team** button.
#
# After you import your private workforce, refresh the page. On the Private workforce summary page, you'll see your work team ARN. Enter this ARN in the following cell.

# %%
##Use Beta Private Team till GA
workteam_arn = ""

# %% [markdown]
# #### Task Time Limits
#
# 3D point cloud annotation jobs can take workers hours. Workers will be able to save their work as they go, and complete the task in multiple sittings. Ground Truth will also automatically save workers' annotations periodically as they work.
#
# When you configure your task, you can set the total amount of time that workers can work on each task when you create a labeling job using `TaskTimeLimitInSeconds`. The maximum time you can set for workers to work on tasks is 7 days. The default value is 3 days. It is recommended that you create labeling tasks that can be completed within 12 hours.
#
# If you set `TaskTimeLimitInSeconds` to be greater than 8 hours, you must set `MaxSessionDuration` for your IAM execution to at least 8 hours. To update your execution role's `MaxSessionDuration`, use [UpdateRole](https://docs.aws.amazon.com/IAM/latest/APIReference/API_UpdateRole.html) or use the [IAM console](https://docs.aws.amazon.com/IAM/latest/UserGuide/roles-managingrole-editing-console.html#roles-modify_max-session-duration). You an identify the name of your role at the end of your role ARN.

# %%
# See your execution role ARN. The role name is located at the end of the ARN.
role
# Out:
# 'arn:aws:iam::160885266928:role/service-role/AmazonSageMakerServiceCatalogProductsUseRole'

# %%
ac_arn_map = {
    "us-west-2": "081040173940",
    "us-east-1": "432418664414",
    "us-east-2": "266458841044",
    "eu-west-1": "568282634449",
    "ap-northeast-1": "477331159723",
}

prehuman_arn = "arn:aws:lambda:{}:{}:function:PRE-{}".format(region, ac_arn_map[region], task_type)
acs_arn = "arn:aws:lambda:{}:{}:function:ACS-{}".format(region, ac_arn_map[region], task_type)

# %% [markdown]
# ## Set Up HumanTaskConfig
#
# `HumanTaskConfig` is used to specify your work team, and configure your labeling job tasks. Modify the following cell to identify a `task_description`, `task_keywords`, `task_title`, and `job_name`.

# %%
from datetime import datetime

## Set up Human Task Config

## Modify the following
task_description = "add a task description here"
# example keywords
task_keywords = ["lidar", "pointcloud"]
# add a task title
task_title = "Add a Task Title Here - This is Displayed to Workers"
# add a job name to identify your labeling job
job_name = "add-job-name"

human_task_config = {
    "AnnotationConsolidationConfig": {
        "AnnotationConsolidationLambdaArn": acs_arn,
    },
    "UiConfig": {
        "HumanTaskUiArn": human_task_ui_arn,
    },
    "WorkteamArn": workteam_arn,
    "PreHumanTaskLambdaArn": prehuman_arn,
    "MaxConcurrentTaskCount": 200,  # 200 images will be sent at a time to the workteam.
    "NumberOfHumanWorkersPerDataObject": 1,  # One worker will work on each task
    "TaskAvailabilityLifetimeInSeconds": 18000,  # Your workteam has 5 hours to complete all pending tasks.
    "TaskDescription": task_description,
    "TaskKeywords": task_keywords,
    "TaskTimeLimitInSeconds": 3600,  # Each seq must be labeled within 1 hour.
    "TaskTitle": task_title,
}

# %%
print(json.dumps(human_task_config, indent=4, sort_keys=True))
# Out:
# {
#     "AnnotationConsolidationConfig": {
#         "AnnotationConsolidationLambdaArn": "arn:aws:lambda:us-east-2:266458841044:function:ACS-3DPointCloudObjectTracking"
#     },
#     "MaxConcurrentTaskCount": 200,
#     "NumberOfHumanWorkersPerDataObject": 1,
#     "PreHumanTaskLambdaArn": "arn:aws:lambda:us-east-2:266458841044:function:PRE-3DPointCloudObjectTracking",
#     "TaskAvailabilityLifetimeInSeconds": 18000,
#     "TaskDescription": "add a task description here",
#     "TaskKeywords": [
#         "lidar",
#         "pointcloud"
#     ],
#     "TaskTimeLimitInSeconds": 3600,
#     "TaskTitle": "Add a Task Title Here - This is Displayed to Workers",
#     "UiConfig": {
#         "HumanTaskUiArn": "arn:aws:sagemaker:us-east-2:394669845002:human-task-ui/PointCloudObjectTracking"
#     },
#     "WorkteamArn": ""
# }

# %% [markdown]
# ## Set up Create Labeling Request

# %% [markdown]
# The following formats your labeling job request. For Object Tracking task types, the `LabelAttributeName` must end in `-ref`.

# %%
if EXP_NAME == "":
    s3_output_path = f"s3://{BUCKET}"
else:
    s3_output_path = f"s3://{BUCKET}/{EXP_NAME}"
s3_output_path
# Out:
# 's3://ground-truth-bucket-aa/test'

# %%
## Set up Create Labeling Request

labelAttributeName = job_name + "-ref"

if (
    task_type == "3DPointCloudObjectDetection"
    or task_type == "Adjustment3DPointCloudObjectDetection"
):
    labelAttributeName = job_name


ground_truth_request = {
    "InputConfig": {
        "DataSource": {
            "S3DataSource": {
                "ManifestS3Uri": input_manifest_s3uri,
            }
        },
        "DataAttributes": {
            "ContentClassifiers": ["FreeOfPersonallyIdentifiableInformation", "FreeOfAdultContent"]
        },
    },
    "OutputConfig": {
        "S3OutputPath": s3_output_path,
    },
    "HumanTaskConfig": human_task_config,
    "LabelingJobName": job_name,
    "RoleArn": role,
    "LabelAttributeName": labelAttributeName,
    "LabelCategoryConfigS3Uri": label_category_config_s3uri,
}

print(json.dumps(ground_truth_request, indent=4, sort_keys=True))
# Out:
# {
#     "HumanTaskConfig": {
#         "AnnotationConsolidationConfig": {
#             "AnnotationConsolidationLambdaArn": "arn:aws:lambda:us-east-2:266458841044:function:ACS-3DPointCloudObjectTracking"
#         },
#         "MaxConcurrentTaskCount": 200,
#         "NumberOfHumanWorkersPerDataObject": 1,
#         "PreHumanTaskLambdaArn": "arn:aws:lambda:us-east-2:266458841044:function:PRE-3DPointCloudObjectTracking",
#         "TaskAvailabilityLifetimeInSeconds": 18000,
#         "TaskDescription": "add a task description here",
#         "TaskKeywords": [
#             "lidar",
#             "pointcloud"
#         ],
#         "TaskTimeLimitInSeconds": 3600,
#         "TaskTitle": "Add a Task Title Here - This is Displayed to Workers",
#         "UiConfig": {
#             "HumanTaskUiArn": "arn:aws:sagemaker:us-east-2:394669845002:human-task-ui/PointCloudObjectTracking"
#         },
#         "WorkteamArn": ""
#     },
#     "InputConfig": {
#         "DataAttributes": {
#             "ContentClassifiers": [
#                 "FreeOfPersonallyIdentifiableInformation",
#                 "FreeOfAdultContent"
#             ]
#         },
#         "DataSource": {
#             "S3DataSource": {
#                 "ManifestS3Uri": "s3://ground-truth-bucket-aa/test/manifest.json"
#             }
#         }
#     },
#     "LabelAttributeName": "add-job-name-ref",
#     "LabelCategoryConfigS3Uri": "s3://ground-truth-bucket-aa/test/label-category.json",
#     "LabelingJobName": "add-job-name",
#     "OutputConfig": {
#         "S3OutputPath": "s3://ground-truth-bucket-aa/test"
#     },
#     "RoleArn": "arn:aws:iam::160885266928:role/service-role/AmazonSageMakerServiceCatalogProductsUseRole"
# }

# %% [markdown]
# ## Call CreateLabelingJob

# %%
sagemaker_client.create_labeling_job(**ground_truth_request)
print(f"Labeling Job Name: {job_name}")
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 sagemaker_client.create_labeling_job(**ground_truth_request)                                 │
# │   2 print(f"Labeling Job Name: {job_name}")                                                      │
# │   3                                                                                              │
# │                                                                                                  │
# │ /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/client.py:570 in     │
# │ _api_call                                                                                        │
# │                                                                                                  │
# │    567 │   │   │   │   │   f"{py_operation_name}() only accepts keyword arguments."              │
# │    568 │   │   │   │   )                                                                         │
# │    569 │   │   │   # The "self" in this scope is referring to the BaseClient.                    │
# │ ❱  570 │   │   │   return self._make_api_call(operation_name, kwargs)                            │
# │    571 │   │                                                                                     │
# │    572 │   │   _api_call.__name__ = str(py_operation_name)                                       │
# │    573                                                                                           │
# │                                                                                                  │
# │ /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/context.py:124 in    │
# │ wrapper                                                                                          │
# │                                                                                                  │
# │   121 │   │   │   with start_as_current_context():                                               │
# │   122 │   │   │   │   if hook:                                                                   │
# │   123 │   │   │   │   │   hook()                                                                 │
# │ ❱ 124 │   │   │   │   return func(*args, **kwargs)                                               │
# │   125 │   │                                                                                      │
# │   126 │   │   return wrapper                                                                     │
# │   127                                                                                            │
# │                                                                                                  │
# │ /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/client.py:1031 in    │
# │ _make_api_call                                                                                   │
# │                                                                                                  │
# │   1028 │   │   │   │   "Code"                                                                    │
# │   1029 │   │   │   )                                                                             │
# │   1030 │   │   │   error_class = self.exceptions.from_code(error_code)                           │
# │ ❱ 1031 │   │   │   raise error_class(parsed_response, operation_name)                            │
# │   1032 │   │   else:                                                                             │
# │   1033 │   │   │   return parsed_response                                                        │
# │   1034                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ClientError: An error occurred (ValidationException) when calling the CreateLabelingJob operation: 1 validation
# error detected: Value '' at 'humanTaskConfig.workteamArn' failed to satisfy constraint: Member must satisfy regular
# expression pattern: arn:aws[a-z\-]*:sagemaker:[a-z0-9\-]*:[0-9]{12}:workteam/.*

# %% [markdown]
# ## Check Status of Labeling Job

# %%
## call describeLabelingJob
describeLabelingJob = sagemaker_client.describe_labeling_job(LabelingJobName=job_name)
print(describeLabelingJob)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:2                                                                                    │
# │                                                                                                  │
# │   1 ## call describeLabelingJob                                                                  │
# │ ❱ 2 describeLabelingJob = sagemaker_client.describe_labeling_job(LabelingJobName=job_name)       │
# │   3 print(describeLabelingJob)                                                                   │
# │   4                                                                                              │
# │                                                                                                  │
# │ /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/client.py:570 in     │
# │ _api_call                                                                                        │
# │                                                                                                  │
# │    567 │   │   │   │   │   f"{py_operation_name}() only accepts keyword arguments."              │
# │    568 │   │   │   │   )                                                                         │
# │    569 │   │   │   # The "self" in this scope is referring to the BaseClient.                    │
# │ ❱  570 │   │   │   return self._make_api_call(operation_name, kwargs)                            │
# │    571 │   │                                                                                     │
# │    572 │   │   _api_call.__name__ = str(py_operation_name)                                       │
# │    573                                                                                           │
# │                                                                                                  │
# │ /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/context.py:124 in    │
# │ wrapper                                                                                          │
# │                                                                                                  │
# │   121 │   │   │   with start_as_current_context():                                               │
# │   122 │   │   │   │   if hook:                                                                   │
# │   123 │   │   │   │   │   hook()                                                                 │
# │ ❱ 124 │   │   │   │   return func(*args, **kwargs)                                               │
# │   125 │   │                                                                                      │
# │   126 │   │   return wrapper                                                                     │
# │   127                                                                                            │
# │                                                                                                  │
# │ /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/client.py:1031 in    │
# │ _make_api_call                                                                                   │
# │                                                                                                  │
# │   1028 │   │   │   │   "Code"                                                                    │
# │   1029 │   │   │   )                                                                             │
# │   1030 │   │   │   error_class = self.exceptions.from_code(error_code)                           │
# │ ❱ 1031 │   │   │   raise error_class(parsed_response, operation_name)                            │
# │   1032 │   │   else:                                                                             │
# │   1033 │   │   │   return parsed_response                                                        │
# │   1034                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ClientError: An error occurred (ValidationException) when calling the DescribeLabelingJob operation: Requested
# resource not found.

# %% [markdown]
# ## Start Working on tasks
#
# When you add yourself to a private work team, you recieve an email invitation to access the worker portal that looks similar to this [image](https://d2908q01vomqb2.cloudfront.net/f1f836cb4ea6efb2a0b1b99f41ad8b103eff4b59/2020/04/16/a2i-critical-documents-26.gif). Use this invitation to sign in to the protal and view your 3D point cloud annotation tasks. Tasks may take up to 10 minutes to show up the worker portal.
#
# Once you are done working on the tasks, click **Submit**.

# %% [markdown]
# ### View Output Data
#
# Once you have completed all of the tasks, you can view your output data in the S3 location you specified in `OutputConfig`.
#
# To read more about Ground Truth output data format for your task type, see [Output Data](https://docs.aws.amazon.com/sagemaker/latest/dg/sms-data-output.html#sms-output-point-cloud-object-tracking).

# %% [markdown]
# ## Acknowledgments
#
# We would like to thank the KITTI team for letting us use this dataset to demonstrate how to prepare your 3D point cloud data for use in SageMaker Ground Truth.

# %% [markdown]
# ## Notebook CI Test Results
#
# This notebook was tested in multiple regions. The test results are as follows, except for us-west-2 which is shown at the top of the notebook.
#
# ![This us-east-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/us-east-1/ground_truth_labeling_jobs|3d_point_cloud_input_data_processing|3D-point-cloud-input-data-processing.ipynb)
#
# ![This us-east-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/us-east-2/ground_truth_labeling_jobs|3d_point_cloud_input_data_processing|3D-point-cloud-input-data-processing.ipynb)
#
# ![This us-west-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/us-west-1/ground_truth_labeling_jobs|3d_point_cloud_input_data_processing|3D-point-cloud-input-data-processing.ipynb)
#
# ![This ca-central-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ca-central-1/ground_truth_labeling_jobs|3d_point_cloud_input_data_processing|3D-point-cloud-input-data-processing.ipynb)
#
# ![This sa-east-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/sa-east-1/ground_truth_labeling_jobs|3d_point_cloud_input_data_processing|3D-point-cloud-input-data-processing.ipynb)
#
# ![This eu-west-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/eu-west-1/ground_truth_labeling_jobs|3d_point_cloud_input_data_processing|3D-point-cloud-input-data-processing.ipynb)
#
# ![This eu-west-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/eu-west-2/ground_truth_labeling_jobs|3d_point_cloud_input_data_processing|3D-point-cloud-input-data-processing.ipynb)
#
# ![This eu-west-3 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/eu-west-3/ground_truth_labeling_jobs|3d_point_cloud_input_data_processing|3D-point-cloud-input-data-processing.ipynb)
#
# ![This eu-central-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/eu-central-1/ground_truth_labeling_jobs|3d_point_cloud_input_data_processing|3D-point-cloud-input-data-processing.ipynb)
#
# ![This eu-north-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/eu-north-1/ground_truth_labeling_jobs|3d_point_cloud_input_data_processing|3D-point-cloud-input-data-processing.ipynb)
#
# ![This ap-southeast-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ap-southeast-1/ground_truth_labeling_jobs|3d_point_cloud_input_data_processing|3D-point-cloud-input-data-processing.ipynb)
#
# ![This ap-southeast-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ap-southeast-2/ground_truth_labeling_jobs|3d_point_cloud_input_data_processing|3D-point-cloud-input-data-processing.ipynb)
#
# ![This ap-northeast-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ap-northeast-1/ground_truth_labeling_jobs|3d_point_cloud_input_data_processing|3D-point-cloud-input-data-processing.ipynb)
#
# ![This ap-northeast-2 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ap-northeast-2/ground_truth_labeling_jobs|3d_point_cloud_input_data_processing|3D-point-cloud-input-data-processing.ipynb)
#
# ![This ap-south-1 badge failed to load. Check your device's internet connectivity, otherwise the service is currently unavailable](https://prod.us-west-2.tcx-beacon.docs.aws.dev/sagemaker-nb/ap-south-1/ground_truth_labeling_jobs|3d_point_cloud_input_data_processing|3D-point-cloud-input-data-processing.ipynb)
